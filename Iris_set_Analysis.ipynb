# %%
#Importing required libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # The Iris dataset is a well-known dataset and it contains measurements of iris flowers.
# ## Q1. Rename the columns of the dataset to 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', and 'Species'

# %%
#Importing the iris_datset using pd.read_csv()
df=pd.read_csv(r"C:\Users\RAGHAVENDRA KUMAR\Downloads\2732079-Datasets (1)\Datasets\iris.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#      Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0             0                5.1               3.5                1.4
# 1             1                4.9               3.0                1.4
# 2             2                4.7               3.2                1.3
# 3             3                4.6               3.1                1.5
# 4             4                5.0               3.6                1.4
# ..          ...                ...               ...                ...
# 145         145                6.7               3.0                5.2
# 146         146                6.3               2.5                5.0
# 147         147                6.5               3.0                5.2
# 148         148                6.2               3.4                5.4
# 149         149                5.9               3.0                5.1
#
#      petal width (cm)  target target_names
# 0                 0.2       0       setosa
# ...

# %%
df1=df.drop(columns="Unnamed: 0")

# %%
df1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target target_names
# ...

# %%
#Renaming the columns using rename()
df1=df1.rename(columns={"sepal length (cm)":"SepalLength","sepal width (cm)":"SepalWidth","petal length (cm)":"PetalLength","petal width (cm)":"PetalWidth","target_names":"Species"})

# %%
df1
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target    Species
# 0            5.1         3.5          1.4         0.2       0     setosa
# 1            4.9         3.0          1.4         0.2       0     setosa
# 2            4.7         3.2          1.3         0.2       0     setosa
# 3            4.6         3.1          1.5         0.2       0     setosa
# 4            5.0         3.6          1.4         0.2       0     setosa
# ..           ...         ...          ...         ...     ...        ...
# 145          6.7         3.0          5.2         2.3       2  virginica
# 146          6.3         2.5          5.0         1.9       2  virginica
# 147          6.5         3.0          5.2         2.0       2  virginica
# 148          6.2         3.4          5.4         2.3       2  virginica
# 149          5.9         3.0          5.1         1.8       2  virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # Q2.
# ## a.Set the index of the DataFrame to the 'Species' column.

# %%
df1.set_index("Species")
# Out:
#            SepalLength  SepalWidth  PetalLength  PetalWidth  target
# Species
# setosa             5.1         3.5          1.4         0.2       0
# setosa             4.9         3.0          1.4         0.2       0
# setosa             4.7         3.2          1.3         0.2       0
# setosa             4.6         3.1          1.5         0.2       0
# setosa             5.0         3.6          1.4         0.2       0
# ...                ...         ...          ...         ...     ...
# virginica          6.7         3.0          5.2         2.3       2
# virginica          6.3         2.5          5.0         1.9       2
# virginica          6.5         3.0          5.2         2.0       2
# virginica          6.2         3.4          5.4         2.3       2
# virginica          5.9         3.0          5.1         1.8       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ##  b.Retrieve the first 10 rows of the DataFrame using integer-based indexing.

# %%
df1.iloc[0:10]
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  target Species
# 0          5.1         3.5          1.4         0.2       0  setosa
# 1          4.9         3.0          1.4         0.2       0  setosa
# 2          4.7         3.2          1.3         0.2       0  setosa
# 3          4.6         3.1          1.5         0.2       0  setosa
# 4          5.0         3.6          1.4         0.2       0  setosa
# 5          5.4         3.9          1.7         0.4       0  setosa
# 6          4.6         3.4          1.4         0.3       0  setosa
# 7          5.0         3.4          1.5         0.2       0  setosa
# 8          4.4         2.9          1.4         0.2       0  setosa
# 9          4.9         3.1          1.5         0.1       0  setosa

# %% [markdown]
# # Q3.
# ## a.Slice the DataFrame to display rows with 'PetalWidth' greater than 2.5.

# %%
df1.loc[(df1["PetalWidth"]>2.5)]
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, target, Species]
# Index: []

# %% [markdown]
# ## b.Slice the DataFrame to display columns 'SepalLength' and 'SepalWidth' for the first 5 rows.

# %%
df1.loc[0:4,"SepalLength":"SepalWidth"]
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %%
df1.iloc[0:5,0:2]
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %%
df1[["SepalLength","SepalWidth"]].head()
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %% [markdown]
# # Q4.
# ## a.Filter the DataFrame to show only rows where 'Species' is 'versicolor'.

# %%
df1.loc[(df1["Species"]=="versicolor")]
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth  target     Species
# 50          7.0         3.2          4.7         1.4       1  versicolor
# 51          6.4         3.2          4.5         1.5       1  versicolor
# 52          6.9         3.1          4.9         1.5       1  versicolor
# 53          5.5         2.3          4.0         1.3       1  versicolor
# 54          6.5         2.8          4.6         1.5       1  versicolor
# 55          5.7         2.8          4.5         1.3       1  versicolor
# 56          6.3         3.3          4.7         1.6       1  versicolor
# 57          4.9         2.4          3.3         1.0       1  versicolor
# 58          6.6         2.9          4.6         1.3       1  versicolor
# 59          5.2         2.7          3.9         1.4       1  versicolor
# 60          5.0         2.0          3.5         1.0       1  versicolor
# 61          5.9         3.0          4.2         1.5       1  versicolor
# ...

# %% [markdown]
# ## b.Filter the DataFrame to show rows where 'PetalLength' is greater than 4 and 'SepalWidth' is less than 3.

# %%
df1.loc[(df1["PetalLength"]>4) & (df1["SepalWidth"]<3)]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target     Species
# 54           6.5         2.8          4.6         1.5       1  versicolor
# 55           5.7         2.8          4.5         1.3       1  versicolor
# 58           6.6         2.9          4.6         1.3       1  versicolor
# 63           6.1         2.9          4.7         1.4       1  versicolor
# 67           5.8         2.7          4.1         1.0       1  versicolor
# 68           6.2         2.2          4.5         1.5       1  versicolor
# 72           6.3         2.5          4.9         1.5       1  versicolor
# 73           6.1         2.8          4.7         1.2       1  versicolor
# 74           6.4         2.9          4.3         1.3       1  versicolor
# 76           6.8         2.8          4.8         1.4       1  versicolor
# 78           6.0         2.9          4.5         1.5       1  versicolor
# 83           6.0         2.7          5.1         1.6       1  versicolor
# ...

# %% [markdown]
# # Q5.
# ## a.Calculate the minimum 'PetalLength' across all species.

# %%
df1["PetalLength"].min()
# Out:
# 1.0

# %%
print("The minimum PetalLength across all species :",df1["PetalLength"].min())
# Out:
# The minimum PetalLength across all species : 1.0

# %% [markdown]
# ## b.Calculate the maximum 'SepalWidth' across all species.

# %%
df1["SepalWidth"].max()
# Out:
# 4.4

# %%
print("The maximum SepalWidth across all species :",df1["SepalWidth"].max())
# Out:
# The maximum SepalWidth across all species : 4.4

# %% [markdown]
# # Q6.
# ## a.Calculate the sum of values along axis=1 (row-wise).

# %%
df1.sum(axis=1,numeric_only=True)
# Out:
# 0      10.2
# 1       9.5
# 2       9.4
# 3       9.4
# 4      10.2
#        ...
# 145    19.2
# 146    17.7
# 147    18.7
# 148    19.3
# 149    17.8
# Length: 150, dtype: float64

# %% [markdown]
# ## b.Calculate the mean of values along axis=0 (column-wise).

# %%
df1.mean(axis=0,numeric_only=True)
# Out:
# SepalLength    5.843333
# SepalWidth     3.057333
# PetalLength    3.758000
# PetalWidth     1.199333
# target         1.000000
# dtype: float64

# %% [markdown]
# ##  Q7.Add a new column 'PetalArea' calculated as the product of 'PetalLength' and 'PetalWidth'.

# %%
df1["PetalArea"]=df1["PetalLength"]*df1["PetalWidth"]

# %%
df1
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target    Species  \
# 0            5.1         3.5          1.4         0.2       0     setosa
# 1            4.9         3.0          1.4         0.2       0     setosa
# 2            4.7         3.2          1.3         0.2       0     setosa
# 3            4.6         3.1          1.5         0.2       0     setosa
# 4            5.0         3.6          1.4         0.2       0     setosa
# ..           ...         ...          ...         ...     ...        ...
# 145          6.7         3.0          5.2         2.3       2  virginica
# 146          6.3         2.5          5.0         1.9       2  virginica
# 147          6.5         3.0          5.2         2.0       2  virginica
# 148          6.2         3.4          5.4         2.3       2  virginica
# 149          5.9         3.0          5.1         1.8       2  virginica
#
#      PetalArea
# 0         0.28
# 1         0.28
# 2         0.26
# 3         0.30
# ...

# %% [markdown]
# ## Q8.Convert the 'SepalLength' column to float dtype using astype.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   target       150 non-null    int64
#  5   Species      150 non-null    object
#  6   PetalArea    150 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
df1["SepalLength"]=df1["SepalLength"].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    int32
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   target       150 non-null    int64
#  5   Species      150 non-null    object
#  6   PetalArea    150 non-null    float64
# dtypes: float64(4), int32(1), int64(1), object(1)
# memory usage: 7.7+ KB

# %%
df1["SepalLength"]=df1["SepalLength"].astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   target       150 non-null    int64
#  5   Species      150 non-null    object
#  6   PetalArea    150 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %% [markdown]
# ## Q9. Query the DataFrame to show rows where 'PetalLength' is greater than 'SepalLength'.

# %%
df1.loc[(df1["PetalLength"]>df1["SepalLength"]),["SepalLength","PetalLength","Species"]]
# Out:
#      SepalLength  PetalLength    Species
# 101          5.0          5.1  virginica
# 106          4.0          4.5  virginica
# 114          5.0          5.1  virginica
# 142          5.0          5.1  virginica
# 149          5.0          5.1  virginica

# %% [markdown]
# ## Q10. Apply a function to calculate the difference between 'PetalLength' and 'SepalLength' for each row.

# %%
df1.apply(lambda x:x["PetalLength"]-x["SepalLength"],axis=1)
# Out:
# 0     -3.6
# 1     -2.6
# 2     -2.7
# 3     -2.5
# 4     -3.6
#       ...
# 145   -0.8
# 146   -1.0
# 147   -0.8
# 148   -0.6
# 149    0.1
# Length: 150, dtype: float64

# %% [markdown]
# # Q11.
# ## a.Find the top 3 rows with the largest 'PetalLength'

# %%
#Finding the top 3 rows using sort_values()
df1.sort_values(by="PetalLength",ascending=False)[:3]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target    Species  \
# 118          7.0         2.6          6.9         2.3       2  virginica
# 122          7.0         2.8          6.7         2.0       2  virginica
# 117          7.0         3.8          6.7         2.2       2  virginica
#
#      PetalArea
# 118      15.87
# 122      13.40
# 117      14.74

# %%
#Finding the top 3 rows using nlargest()
df1.nlargest(3,"PetalLength")
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target    Species  \
# 118          7.0         2.6          6.9         2.3       2  virginica
# 117          7.0         3.8          6.7         2.2       2  virginica
# 122          7.0         2.8          6.7         2.0       2  virginica
#
#      PetalArea
# 118      15.87
# 117      14.74
# 122      13.40

# %% [markdown]
# ## b.Find the top 3 rows with the smallest 'SepalWidth'.

# %%
df1.sort_values(by="SepalWidth")[:3]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target     Species  \
# 60           5.0         2.0          3.5         1.0       1  versicolor
# 62           6.0         2.2          4.0         1.0       1  versicolor
# 119          6.0         2.2          5.0         1.5       2   virginica
#
#      PetalArea
# 60         3.5
# 62         4.0
# 119        7.5

# %%
df1.nsmallest(3,"SepalWidth")
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth  target     Species  \
# 60          5.0         2.0          3.5         1.0       1  versicolor
# 62          6.0         2.2          4.0         1.0       1  versicolor
# 68          6.0         2.2          4.5         1.5       1  versicolor
#
#     PetalArea
# 60       3.50
# 62       4.00
# 68       6.75

# %% [markdown]
# # Q12.
# ## a.Sort the DataFrame by 'PetalWidth' in ascending order.

# %%
df1.sort_values(by="PetalWidth")
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target    Species  \
# 32           5.0         4.1          1.5         0.1       0     setosa
# 13           4.0         3.0          1.1         0.1       0     setosa
# 37           4.0         3.6          1.4         0.1       0     setosa
# 9            4.0         3.1          1.5         0.1       0     setosa
# 12           4.0         3.0          1.4         0.1       0     setosa
# ..           ...         ...          ...         ...     ...        ...
# 140          6.0         3.1          5.6         2.4       2  virginica
# 114          5.0         2.8          5.1         2.4       2  virginica
# 100          6.0         3.3          6.0         2.5       2  virginica
# 144          6.0         3.3          5.7         2.5       2  virginica
# 109          7.0         3.6          6.1         2.5       2  virginica
#
#      PetalArea
# 32        0.15
# 13        0.11
# 37        0.14
# 9         0.15
# ...

# %% [markdown]
# ##  b.Sort the DataFrame by 'SepalLength' in descending order.

# %%
df1.sort_values(by="SepalLength",ascending=False)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  target     Species  \
# 109          7.0         3.6          6.1         2.5       2   virginica
# 135          7.0         3.0          6.1         2.3       2   virginica
# 107          7.0         2.9          6.3         1.8       2   virginica
# 105          7.0         3.0          6.6         2.1       2   virginica
# 117          7.0         3.8          6.7         2.2       2   virginica
# ..           ...         ...          ...         ...     ...         ...
# 57           4.0         2.4          3.3         1.0       1  versicolor
# 22           4.0         3.6          1.0         0.2       0      setosa
# 29           4.0         3.2          1.6         0.2       0      setosa
# 24           4.0         3.4          1.9         0.2       0      setosa
# 41           4.0         2.3          1.3         0.3       0      setosa
#
#      PetalArea
# 109      15.25
# 135      14.03
# 107      11.34
# ...
